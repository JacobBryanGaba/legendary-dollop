# %% [markdown]
# # Dataset Description
# From a list of restaurants and their respective sales, this data set ranks the restaurants from best to worst in terms of their sales and the types of food they offer.

# %%
# Data analysis and data preparation
import pandas as pd
import numpy as np
import random as rnd

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Use pd.read_csv for the vgsales.csv that was downloaded.
games_df = pd.read_csv('data/vgsales.csv')

# %% [markdown]
# # Exploring the Dataset
# Display the dataset's contents to inspect the kind of data being dealt with.

# %%
# Display the first 10 rows, using head, of the video games dataframe
games_df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
# Display the last 10 rows, using tail, of the video games dataframe
games_df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
# Display the shape of the data (display row and column number)
games_df.shape
# Out:
# (16598, 11)

# %%
# Display the names of the columns
games_df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Display the number of unique values
games_df.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %% [markdown]
# # Data Preparation
# Clean the data based on what we want to find out about the data. Remove any outliers, null values, or unnecessary columns to make the data tidy.

# %%
# Display the total number of null values present in the data

games_df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# Since the information included in all the columns are deemed significant, no entire columns will be dropped during this preparaion. However, since the columns Year and Publisher columns contain null values, corresponding rows will be removed.

# %%
# Remove the rows with null values

vgames_df = games_df.dropna()

# %% [markdown]
# ### Display Tidied Dataset for vgsales.csv

# %%
vgames_df.head(100)
# Out:
#     Rank                                    Name Platform    Year  \
# 0      1                              Wii Sports      Wii  2006.0
# 1      2                       Super Mario Bros.      NES  1985.0
# 2      3                          Mario Kart Wii      Wii  2008.0
# 3      4                       Wii Sports Resort      Wii  2009.0
# 4      5                Pokemon Red/Pokemon Blue       GB  1996.0
# ..   ...                                     ...      ...     ...
# 95    96  Crash Bandicoot 2: Cortex Strikes Back       PS  1997.0
# 96    97                     Super Mario Bros. 2      NES  1988.0
# 97    98     Super Smash Bros. for Wii U and 3DS      3DS  2014.0
# 98    99              Call of Duty: World at War     X360  2008.0
# 99   100                           Battlefield 3     X360  2011.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                     Nintendo     41.49     29.02      3.77
# ...

# %% [markdown]
# # Data Analysis
# This section shows observations and analyses regarding the explored dataset.

# %% [markdown]
# ### Statistics
# View the statistical analysis of the current dataframe. Measure the mean, the standard deviation, and the minimum and maximum values of the global sales of the video games included in the dataframe.

# %%
# Describe the Global Sales column of the vgames_df dataframe to display its statistics
vgames_df['Global_Sales'].describe()
# Out:
# count    16291.000000
# mean         0.540910
# std          1.567345
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.480000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
# Display rows in the dataset wherein the Global Sales amount starts becoming less than the mean
vgames_df.loc[3755:]
# Out:
#         Rank                                              Name Platform  \
# 3755    3757                      Star Wars Battlefront (2015)       PC
# 3756    3758    Sakura Taisen 2 - Kimi, Shinitamou Koto Nakare      SAT
# 3757    3759                                Jewel Master Egypt       DS
# 3758    3760                                    Time Crisis II      PS2
# 3759    3761                                       Clock Tower       PS
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year      Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Due to the significant difference between the maximum and minimum values of the Global Sales in the dataset, only 22.63% of the video games in the entire list meet the mean of all the sales. Starting from Rank 3758, the video games are below average in terms of sales.
#
# Looking at the top of the rankings list however, it can be seen that the video games comprising the top 100 of the list have over 13 times more sales than the calculated average global sales value. This shows that companies considered video game giants have reputations that allow them to dominate the video game market. One such example is the company Nintendo which takes up the entire top 10 list of video games with the most global sales.

# %% [markdown]
# ## Significance of Platform, Genre, and Publisher with Video Games Sales Amount

# %% [markdown]
# ### Analyzing the effect of a video game's platform to its sales success
# To further analyze the factors that contribute to the global sales amount, the rankings of video games belonging to major platforms are shown below.

# %%
# Display the unique values of column Platform

vgames_df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# To find a reasoning behind the success of all the video games found in the list, the following kernel counts the number of number of video games grouped into their respective platforms.

# %%
a = vgames_df['Platform'].value_counts()
a.head(31)
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %% [markdown]
# Based on the results of the previous operation, there appears to be certain platforms which are more popular and hence receive more attention than other platforms. For instance, DS, PS2, PS3, Wii, X360, PSP, and PS all have over 1,000 games in the video games data frame. This is to note that over 1,000 games have receieved at least 100,000 global sales. This means that there are over 100,000,000 copies of video games belonging to these platforms which have already been sold.

# %% [markdown]
# The following section filters the list based on the top 5 platforms in order to find a correlation between a video game's platform and its global sales ranking.

# %%
is_DS = vgames_df.Platform.str.match("DS")
vgames_df[is_DS].head(10)
# Out:
#     Rank                                          Name Platform    Year  \
# 6      7                         New Super Mario Bros.       DS  2006.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# 19    20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
# 20    21                 Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 26    27                   Pokemon Black/Pokemon White       DS  2010.0
# 27    28   Brain Age 2: More Training in Minutes a Day       DS  2005.0
# 41    42                   Animal Crossing: Wild World       DS  2005.0
# 45    46          Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0
# 59    60                                Super Mario 64       DS  2004.0
#
#            Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 6       Platform  Nintendo     11.38      9.23      6.50         2.90
# ...

# %%
is_PS2 = vgames_df.Platform.str.match("PS2")
vgames_df[is_PS2].head(10)
# Out:
#      Rank                           Name Platform    Year         Genre  \
# 17     18  Grand Theft Auto: San Andreas      PS2  2004.0        Action
# 24     25    Grand Theft Auto: Vice City      PS2  2002.0        Action
# 28     29         Gran Turismo 3: A-Spec      PS2  2001.0        Racing
# 38     39           Grand Theft Auto III      PS2  2001.0        Action
# 47     48                 Gran Turismo 4      PS2  2004.0        Racing
# 86     87                Final Fantasy X      PS2  2001.0  Role-Playing
# 104   105     Need for Speed Underground      PS2  2003.0        Racing
# 113   114   Need for Speed Underground 2      PS2  2004.0        Racing
# 114   115      Medal of Honor: Frontline      PS2  2002.0       Shooter
# 131   132                 Kingdom Hearts      PS2  2002.0  Role-Playing
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17          Take-Two Interactive      9.43      0.40      0.41        10.57
# ...

# %% [markdown]
# Judging from the rankings of the restaurants under Quick Service and Fast Casual, the speed at which customers are served is a necessary factor in a restaurant's success. The top 14 in the list are classified under one of these two categories.

# %%
is_PS3 = vgames_df.Platform.str.match("PS3")
vgames_df[is_PS3].head(10)
# Out:
#      Rank                            Name Platform    Year    Genre  \
# 16     17              Grand Theft Auto V      PS3  2013.0   Action
# 34     35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 37     38  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 40     41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 54     55                  Gran Turismo 5      PS3  2010.0   Racing
# 55     56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 56     57             Grand Theft Auto IV      PS3  2008.0   Action
# 67     68            Call of Duty: Ghosts      PS3  2013.0  Shooter
# 82     83                  FIFA Soccer 13      PS3  2012.0   Action
# 103   104                   Battlefield 3      PS3  2011.0  Shooter
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16          Take-Two Interactive      7.01      9.27      0.97         4.14
# ...

# %%
is_Wii = vgames_df.Platform.str.match("Wii")
vgames_df[is_Wii].head(10)
# Out:
#     Rank                       Name Platform    Year     Genre Publisher  \
# 0      1                 Wii Sports      Wii  2006.0    Sports  Nintendo
# 2      3             Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3      4          Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 7      8                   Wii Play      Wii  2006.0      Misc  Nintendo
# 8      9  New Super Mario Bros. Wii      Wii  2009.0  Platform  Nintendo
# 13    14                    Wii Fit      Wii  2007.0    Sports  Nintendo
# 14    15               Wii Fit Plus      Wii  2009.0    Sports  Nintendo
# 39    40    Super Smash Bros. Brawl      Wii  2008.0  Fighting  Nintendo
# 48    49         Super Mario Galaxy      Wii  2007.0  Platform  Nintendo
# 60    61               Just Dance 3      Wii  2011.0      Misc   Ubisoft
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      41.49     29.02      3.77         8.46         82.74
# ...

# %%
is_X360 = vgames_df.Platform.str.match("X360")
vgames_df[is_X360].head(10)
# Out:
#     Rank                            Name Platform    Year    Genre  \
# 15    16              Kinect Adventures!     X360  2010.0     Misc
# 23    24              Grand Theft Auto V     X360  2013.0   Action
# 29    30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36    37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 43    44                          Halo 3     X360  2007.0  Shooter
# 51    52             Grand Theft Auto IV     X360  2008.0   Action
# 61    62            Call of Duty: Ghosts     X360  2013.0  Shooter
# 62    63                     Halo: Reach     X360  2010.0  Shooter
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 15  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 23    Take-Two Interactive      9.63      5.31      0.06         1.38
# ...

# %% [markdown]
# Despite having the most number of games belonging in the list out of all the platforms, DS games are not necessarily the most popular. While Wii games have almost 900 games less belonging to the rankings list, the games in the Wii platform are more popular than that of the DS platform with Wii games occupying 5 out of 10 games in the overall top 10 rankings based on global sales.

# %% [markdown]
# ### Analyzing the effect of a video game's genre to its sales success
# To further analyze the factors that contribute to the global sales amount, the rankings of video games belonging to different genres are shown below.

# %%
# Display the unique values of column Genre

vgames_df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# To find a reasoning behind the success of all the video games found in the list, the following kernel counts the number of number of video games grouped into their respective genres.

# %%
b = vgames_df['Genre'].value_counts()
b.head(12)
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %% [markdown]
# Similar to the earlier analysis with the Platform column, certain Genres are more warmly welcomed than others. The action genre has over twice as more games in the dataset compared to most other genres with the exception of the Sports and Miscellaneous genres.

# %% [markdown]
# The following section filters the list based on the top 5 genres in order to find a correlation between a video game's genre and its global sales ranking.

# %%
is_Action = vgames_df.Genre.str.match("Action")
vgames_df[is_Action].head(10)
# Out:
#     Rank                                  Name Platform    Year   Genre  \
# 16    17                    Grand Theft Auto V      PS3  2013.0  Action
# 17    18         Grand Theft Auto: San Andreas      PS2  2004.0  Action
# 23    24                    Grand Theft Auto V     X360  2013.0  Action
# 24    25           Grand Theft Auto: Vice City      PS2  2002.0  Action
# 38    39                  Grand Theft Auto III      PS2  2001.0  Action
# 44    45                    Grand Theft Auto V      PS4  2014.0  Action
# 45    46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0  Action
# 51    52                   Grand Theft Auto IV     X360  2008.0  Action
# 56    57                   Grand Theft Auto IV      PS3  2008.0  Action
# 82    83                        FIFA Soccer 13      PS3  2012.0  Action
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16  Take-Two Interactive      7.01      9.27      0.97         4.14
# ...

# %%
is_Sports = vgames_df.Genre.str.match("Sports")
vgames_df[is_Sports].head(10)
# Out:
#      Rank                                Name Platform    Year   Genre  \
# 0       1                          Wii Sports      Wii  2006.0  Sports
# 3       4                   Wii Sports Resort      Wii  2009.0  Sports
# 13     14                             Wii Fit      Wii  2007.0  Sports
# 14     15                        Wii Fit Plus      Wii  2009.0  Sports
# 77     78                             FIFA 16      PS4  2015.0  Sports
# 85     86  Mario & Sonic at the Olympic Games      Wii  2007.0  Sports
# 112   113                             FIFA 14      PS3  2013.0  Sports
# 117   118                       Zumba Fitness      Wii  2010.0  Sports
# 121   122                             FIFA 12      PS3  2011.0  Sports
# 124   125                             FIFA 15      PS4  2014.0  Sports
#
#            Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0           Nintendo     41.49     29.02      3.77         8.46         82.74
# ...

# %%
is_Misc = vgames_df.Genre.str.match("Misc")
vgames_df[is_Misc].head(10)
# Out:
#      Rank                                          Name Platform    Year  \
# 7       8                                      Wii Play      Wii  2006.0
# 15     16                            Kinect Adventures!     X360  2010.0
# 19     20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
# 60     61                                  Just Dance 3      Wii  2011.0
# 68     69                                  Just Dance 2      Wii  2010.0
# 72     73                                     Minecraft     X360  2013.0
# 74     75                                Mario Party DS       DS  2007.0
# 78     79                                     Wii Party      Wii  2010.0
# 80     81                                 Mario Party 8      Wii  2007.0
# 102   103                                    Just Dance      Wii  2009.0
#
#     Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 7    Misc                Nintendo     14.03      9.20      2.93         2.85
# ...

# %%
is_Role_Playing = vgames_df.Genre.str.match("Role-Playing")
vgames_df[is_Role_Playing].head(10)
# Out:
#     Rank                                       Name Platform    Year  \
# 4      5                   Pokemon Red/Pokemon Blue       GB  1996.0
# 12    13                Pokemon Gold/Pokemon Silver       GB  1999.0
# 20    21              Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 25    26              Pokemon Ruby/Pokemon Sapphire      GBA  2002.0
# 26    27                Pokemon Black/Pokemon White       DS  2010.0
# 30    31    Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# 32    33                        Pokemon X/Pokemon Y      3DS  2013.0
# 49    50  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014.0
# 58    59          Pokemon FireRed/Pokemon LeafGreen      GBA  2004.0
# 66    67                          Final Fantasy VII       PS  1997.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4   Role-Playing                     Nintendo     11.27      8.89     10.22
# ...

# %%
is_Shooter = vgames_df.Genre.str.match("Shooter")
vgames_df[is_Shooter].head(10)
# Out:
#     Rank                            Name Platform    Year    Genre  \
# 9     10                       Duck Hunt      NES  1984.0  Shooter
# 29    30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 33    34       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34    35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36    37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 37    38  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 40    41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 43    44                          Halo 3     X360  2007.0  Shooter
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 9                 Nintendo     26.93      0.63      0.28         0.47
# 29              Activision      9.03      4.28      0.13         1.32
# ...

# %% [markdown]
# Despite having the most number of video games in the dataset, the Action genre is not the most successful in terms of the highest global sales for individual games. This is evidenced by the Action genre not appearing within the top 10 games ranked in the list. Instead, the top 10 is composed of a variety of genres with Platform and Sports being the most successful.

# %% [markdown]
# ### Analyzing the effect of a video game's Publisher to its sales success
# To further analyze the factors that contribute to the global sales amount, the rankings of video games released by different publishers are shown below.

# %%
# Display the unique values of column Publisher

vgames_df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %% [markdown]
# To find a reasoning behind the success of all the video games found in the list, the following kernel counts the number of number of video games grouped into their respective publishers.

# %%
c = vgames_df['Publisher'].value_counts()
c.head(30)
# Out:
# Electronic Arts                           1339
# Activision                                 966
# Namco Bandai Games                         928
# Ubisoft                                    918
# Konami Digital Entertainment               823
# THQ                                        712
# Nintendo                                   696
# Sony Computer Entertainment                682
# Sega                                       632
# Take-Two Interactive                       412
# Capcom                                     376
# Atari                                      347
# Tecmo Koei                                 338
# Square Enix                                231
# Warner Bros. Interactive Entertainment     217
# Disney Interactive Studios                 214
# Eidos Interactive                          196
# Midway Games                               196
# 505 Games                                  192
# Microsoft Game Studios                     189
# ...

# %% [markdown]
# Based on the above operation, it can be seen that a number of publishers have created more games than others which have sold over 100,000 copies of these games. Electronic Arts is the company with the most number of games in this dataset, followed by Activision, Namco Bandai Games, Ubisoft, and Konami Digital Entertainment.

# %% [markdown]
# The following section filters the list based on the top 7 publishers in order to find a correlation between the company behind a video game and its global sales ranking.

# %%
is_EA = vgames_df.Publisher.str.match("Electronic Arts")
vgames_df[is_EA].head(10)
# Out:
#      Rank                          Name Platform    Year       Genre  \
# 77     78                       FIFA 16      PS4  2015.0      Sports
# 82     83                FIFA Soccer 13      PS3  2012.0      Action
# 83     84                    The Sims 3       PC  2009.0  Simulation
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 99    100                 Battlefield 3     X360  2011.0     Shooter
# 103   104                 Battlefield 3      PS3  2011.0     Shooter
# 104   105    Need for Speed Underground      PS2  2003.0      Racing
# 112   113                       FIFA 14      PS3  2013.0      Sports
# 113   114  Need for Speed Underground 2      PS2  2004.0      Racing
# 114   115     Medal of Honor: Frontline      PS2  2002.0     Shooter
#
#            Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77   Electronic Arts      1.11      6.06      0.06         1.26          8.49
# ...

# %%
is_Acti = vgames_df.Publisher.str.match("Activision")
vgames_df[is_Acti].head(10)
# Out:
#     Rank                            Name Platform    Year    Genre  \
# 29    30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 33    34       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34    35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36    37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 37    38  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 40    41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 55    56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 61    62            Call of Duty: Ghosts     X360  2013.0  Shooter
#
#      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 29  Activision      9.03      4.28      0.13         1.32         14.76
# 31  Activision      9.67      3.73      0.11         1.13         14.64
# ...

# %%
is_Namco = vgames_df.Publisher.str.match("Namco Bandai Games")
vgames_df[is_Namco].head(10)
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 264   265                    Namco Museum      GBA  2001.0          Misc
# 294   295           Tekken Tag Tournament      PS2  2000.0      Fighting
# 302   303  Namco Museum: 50th Anniversary      PS2  2005.0          Misc
# 311   312                        Tekken 5      PS2  2005.0      Fighting
# 331   332        The Witcher 3: Wild Hunt      PS4  2015.0  Role-Playing
# 385   386                        Tekken 4      PS2  2002.0      Fighting
# 452   453          World Class Track Meet      NES  1986.0        Sports
# 540   541                        Tekken 6      PS3  2009.0      Fighting
# 737   739       Pro Yakyuu Family Stadium      NES  1986.0        Sports
# 811   813                      Dark Souls      PS3  2011.0  Role-Playing
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 264  Namco Bandai Games      3.00      1.11      0.05         0.07
# ...

# %%
is_Ubisoft = vgames_df.Publisher.str.match("Ubisoft")
vgames_df[is_Ubisoft].head(10)
# Out:
#      Rank                  Name Platform    Year      Genre Publisher  \
# 60     61          Just Dance 3      Wii  2011.0       Misc   Ubisoft
# 68     69          Just Dance 2      Wii  2010.0       Misc   Ubisoft
# 102   103            Just Dance      Wii  2009.0       Misc   Ubisoft
# 111   112          Just Dance 4      Wii  2012.0       Misc   Ubisoft
# 128   129  Assassin's Creed III      PS3  2012.0     Action   Ubisoft
# 156   157   Assassin's Creed II      PS3  2009.0     Action   Ubisoft
# 158   159      Assassin's Creed     X360  2007.0  Adventure   Ubisoft
# 172   173  Assassin's Creed III     X360  2012.0     Action   Ubisoft
# 176   177   Assassin's Creed II     X360  2009.0     Action   Ubisoft
# 218   219      Assassin's Creed      PS3  2007.0  Adventure   Ubisoft
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 60       6.05      3.15      0.00         1.07         10.26
# 68       5.84      2.89      0.01         0.78          9.52
# ...

# %%
is_Konami = vgames_df.Publisher.str.match("Konami Digital Entertainment")
vgames_df[is_Konami].head(10)
# Out:
#      Rank                                         Name Platform    Year  \
# 142   143          Metal Gear Solid 2: Sons of Liberty      PS2  2001.0
# 144   145     Metal Gear Solid 4: Guns of the Patriots      PS3  2008.0
# 145   146                             Metal Gear Solid       PS  1998.0
# 249   250    Winning Eleven: Pro Evolution Soccer 2007      PS2  2006.0
# 265   266              Metal Gear Solid 3: Snake Eater      PS2  2004.0
# 292   293                World Soccer Winning Eleven 9      PS2  2005.0
# 315   316  World Soccer Winning Eleven 8 International      PS2  2004.0
# 348   349                    Pro Evolution Soccer 2008      PS2  2007.0
# 395   396         Metal Gear Solid V: The Phantom Pain      PS4  2015.0
# 474   475  World Soccer Winning Eleven 6 International      PS2  2002.0
#
#       Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 142  Action  Konami Digital Entertainment      2.45      2.01      0.87
# ...

# %%
is_THQ = vgames_df.Publisher.str.match("THQ")
vgames_df[is_THQ].head(10)
# Out:
#      Rank                                Name Platform    Year      Genre  \
# 358   359                      WWF SmackDown!       PS  2000.0   Fighting
# 367   368         Rugrats in Paris: The Movie       PS  2000.0     Action
# 400   401          Rugrats: Search For Reptar       PS  1998.0  Adventure
# 423   424    WWF SmackDown! 2: Know Your Role       PS  2000.0   Fighting
# 461   462                        Saints Row 2     X360  2008.0     Action
# 466   467      WWE SmackDown! Shut Your Mouth      PS2  2002.0     Sports
# 486   487         WWE SmackDown! vs. RAW 2006      PS2  2005.0   Fighting
# 518   519              WWE SmackDown! vs. Raw      PS2  2002.0   Fighting
# 520   521                        Finding Nemo      GBA  2003.0     Action
# 524   525  WWE SmackDown! Here Comes the Pain      PS2  2003.0   Fighting
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 358       THQ      2.01      1.35      0.06         0.16          3.58
# ...

# %%
is_Nintendo = vgames_df.Publisher.str.match("Nintendo")
vgames_df[is_Nintendo].head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# While Electronic Arts does indeed have the most number of games in the market that made it to the rankings list, none of these games made it to the top 10 rankings. The same applies to most of the publishers highlighted in the section above. The publisher that dominated almost the entire top 20 rankings was Nintendo. This shows that quality over quantity is still preferred by video game consumers. Nintendo has become a trusted video game company over the years, and they have continued to receive global recognition for their works.

# %% [markdown]
# ### Correlation between a game's release year and its global sales success
# To further analyze the factors that contribute to the global sales amount, the rankings of video games are categorized below according to their release years. Those before the year 2000 are put into one category while those from 2000 onwards are placed in a different category.

# %%
vgames_df.loc[vgames_df['Year'] < 2000].head(25)
# Out:
#      Rank                                     Name Platform    Year  \
# 1       2                        Super Mario Bros.      NES  1985.0
# 4       5                 Pokemon Red/Pokemon Blue       GB  1996.0
# 5       6                                   Tetris       GB  1989.0
# 9      10                                Duck Hunt      NES  1984.0
# 12     13              Pokemon Gold/Pokemon Silver       GB  1999.0
# 18     19                        Super Mario World     SNES  1990.0
# 21     22                         Super Mario Land       GB  1989.0
# 22     23                      Super Mario Bros. 3      NES  1988.0
# 30     31  Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# 46     47                           Super Mario 64      N64  1996.0
# 50     51       Super Mario Land 2: 6 Golden Coins       GB  1992.0
# 52     53                             Gran Turismo       PS  1997.0
# 57     58                    Super Mario All-Stars     SNES  1993.0
# ...

# %%
vgames_df.loc[vgames_df['Year'] >= 2000].head(25)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# 13    14                                       Wii Fit      Wii  2007.0
# 14    15                                  Wii Fit Plus      Wii  2009.0
# 15    16                            Kinect Adventures!     X360  2010.0
# 16    17                            Grand Theft Auto V      PS3  2013.0
# ...

# %% [markdown]
# Based on the above section, it can be seen that while there are a couple of video game classics that have been recognized and are currently continued to be recognized, most of the games that have found success based on global sales are those that were released in the 21st century. This shows that with the advancements of technology, the quality in which games are created has significantly improved and has thereby been more popular and successful than games of the earlier generation.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Pie chart describing the frequency of each platform for all video games in the list

# %%
vis1 = pd.DataFrame(a)
plot1 = vis1.plot.pie(y ='Platform', autopct='%1.1f%%', label = "Video Game Platforms", fontsize=17, startangle = 25, figsize=(26, 26))

# %% [markdown]
# ### Pie chart describing the frequency of each genre for all video games in the list

# %%
vis2 = pd.DataFrame(b)
plot2 = vis2.plot.pie(y ='Genre', autopct='%1.1f%%', label = "Video Game Genres", fontsize=17, startangle = 25, figsize=(15, 15))

# %% [markdown]
# ### Pie chart describing the frequency of each publisher for the top 100 video games in the list

# %%
c = vgames_df.truncate(after=99)
c = c['Publisher'].value_counts()
c.head(20)
# Out:
# Nintendo                       52
# Activision                     14
# Take-Two Interactive            9
# Sony Computer Entertainment     8
# Microsoft Game Studios          6
# Electronic Arts                 5
# Ubisoft                         2
# SquareSoft                      1
# Atari                           1
# Bethesda Softworks              1
# Sega                            1
# Name: Publisher, dtype: int64

# %%
vis3 = pd.DataFrame(c)
plot3 = vis3.plot.pie(y ='Publisher', autopct='%1.1f%%', label = "Video Game Publishers", fontsize=17, startangle = 25, figsize=(15, 15))

# %% [markdown]
# ### Line chart describing the amount of sales per region of the top 1000 video games indicated in the dataset

# %%
d = vgames_df.truncate(after=999)
vis4 = pd.DataFrame(d)
plot4 = vis4.plot.line(x = 'Rank', y = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'], figsize=(20, 20))
plot4.invert_xaxis()
plot4.set_ylabel('Sales (in millions)')
# Out:
# Text(0, 0.5, 'Sales (in millions)')
